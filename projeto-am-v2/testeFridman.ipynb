# %%
    from utils import utils
    dados = utils.get_base_de_dados()
    dados
# Out:
#        NUC   VAC   POX   ERL   MIT   ALM   GVH   MCG SEQUENCE NAME
# 0     0.58  0.61  0.47  0.13  0.50  0.00  0.48  0.22           MIT
# 1     0.43  0.67  0.48  0.27  0.50  0.00  0.53  0.22           MIT
# 2     0.64  0.62  0.49  0.15  0.50  0.00  0.53  0.22           MIT
# 3     0.58  0.44  0.57  0.13  0.50  0.00  0.54  0.22           NUC
# 4     0.42  0.44  0.48  0.54  0.50  0.00  0.48  0.22           MIT
# ...    ...   ...   ...   ...   ...   ...   ...   ...           ...
# 1479  0.81  0.62  0.43  0.17  0.50  0.00  0.53  0.22           ME2
# 1480  0.47  0.43  0.61  0.40  0.50  0.00  0.48  0.47           NUC
# 1481  0.67  0.57  0.36  0.19  0.50  0.00  0.56  0.22           ME2
# 1482  0.43  0.40  0.60  0.16  0.50  0.00  0.53  0.39           NUC
# 1483  0.65  0.54  0.54  0.13  0.50  0.00  0.53  0.22           CYT
#
# [1484 rows x 9 columns]

# %%
nuc = dados['NUC']
vac = dados['VAC']
pox = dados['POX']
erl = dados['ERL']
mit = dados['MIT']
alm = dados['ALM']
gvh = dados['GVH']
mcg = dados['MCG']

dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1484 entries, 0 to 1483
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   NUC            1484 non-null   object
#  1   VAC            1484 non-null   object
#  2   POX            1484 non-null   object
#  3   ERL            1484 non-null   object
#  4   MIT            1484 non-null   object
#  5   ALM            1484 non-null   object
#  6   GVH            1484 non-null   object
#  7   MCG            1484 non-null   object
#  8   SEQUENCE NAME  1484 non-null   object
# dtypes: object(9)
# memory usage: 104.5+ KB

# %%
from scipy.stats import friedmanchisquare

fs = friedmanchisquare(nuc, vac, pox, erl, mit, alm, gvh, mcg)
fs
# Out:
# FriedmanchisquareResult(statistic=6485.641180080098, pvalue=0.0)

# %%
from scipy import stats
import scikit_posthocs as sp
import numpy as np

stats.friedmanchisquare(nuc, vac, pox, erl, mit, alm, gvh, mcg)

data = np.array([nuc, vac, pox, erl, mit, alm, gvh, mcg])

sp.posthoc_nemenyi_friedman(data.T)
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# <ipython-input-10-267ad1232085> in <module>
#       7 data = np.array([nuc, vac, pox, erl, mit, alm, gvh, mcg])
#       8
# ----> 9 sp.posthoc_nemenyi_friedman(data.T)
#      10
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\scikit_posthocs\_posthocs.py in posthoc_nemenyi_friedman(a, y_col, block_col, group_col, melted, sort)
#     559     n = x[_block_col].unique().size
#     560
# --> 561     x['mat'] = x.groupby(_block_col)[_y_col].rank()
#     562     R = x.groupby(_group_col)['mat'].mean()
#     563     vs = np.zeros((k, k))
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\groupby\groupby.py in rank(self, method, ascending, na_option, pct, axis)
#    2453             msg = "na_option must be one of 'keep', 'top', or 'bottom'"
#    2454             raise ValueError(msg)
# -> 2455         return self._cython_transform(
#    2456             "rank",
#    2457             numeric_only=False,
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\groupby\groupby.py in _cython_transform(self, how, numeric_only, axis, **kwargs)
#     994
#     995         if not output:
# --> 996             raise DataError("No numeric types to aggregate")
#     997
#     998         return self._wrap_transformed_output(output)
#
# DataError: No numeric types to aggregate
